# %%
# !pip install evaluate

# %%
import evaluate

# Load the BLEU evaluation metric
bleu = evaluate.load('bleu')

# Define the additional questions and their variations
additional_predictions = [
    "How can we apply Machine Learning to Hardware?",
    "Explain One-hot encoding and Label Encoding. How do they affect the dimensionality of the given dataset?",
    "When does regularization come into play in Machine Learning?",
    "What is Bias, Variance and what do you mean by Bias-Variance Tradeoff?",
    "How can we relate standard deviation and variance?",
    "A data set is given to you and it has missing values which spread along 1 standard deviation from the mean. How much of the data would remain untouched?",
    "What are some common techniques to handle missing data in a dataset?",
    "Explain the process of feature scaling in machine learning. Why is it important?",
    "What is overfitting in machine learning? How can it be prevented?",
    "Can you explain the concept of cross-validation in machine learning? Why is it important?"
]

additional_references = [
    
        "How do we apply Machine Learning techniques to Hardware?"
    ,
    
        "Define One-hot encoding and Label Encoding. Discuss their impact on dataset dimensionality."
    ,
    
        "When is regularization used in the context of Machine Learning?"
    ,
    
        "Define Bias, Variance, and Bias-Variance Tradeoff in Machine Learning."
    ,
    
        "How are standard deviation and variance related?"
    ,
    
        "If a dataset contains missing values spread within 1 standard deviation from the mean, what proportion of the data remains unaffected?"
    ,
    
        "What methods are commonly used to handle missing data in datasets?"
    ,
    
        "Describe the process of feature scaling in machine learning and its significance."
    ,
    
        "What is overfitting in machine learning and how can it be mitigated?"
    ,
    
        "Can you explain cross-validation in machine learning? Why is it necessary?"
    
]

# Combine the previous questions and references with the additional ones
predictions = []
references = []
predictions = predictions + additional_predictions
references = references + additional_references

# Compute BLEU scores
results = bleu.compute(predictions=predictions, references=references, max_order=2)
print(results)
